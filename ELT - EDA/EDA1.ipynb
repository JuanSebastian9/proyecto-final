# %% [markdown]
# # EDA

# %% [markdown]
# Se verifican los tipos de datos que lee pandas de sqlite vs los tipos de datos de la base de datos NBA_HoopVision con el fin de identificar incompatibilidades y mejorar el proceso de ETL

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine, inspect
import urllib
import sys

# --- Configuración ---
sqlite_db_file = 'nba.sqlite'

sql_server_driver = 'ODBC Driver 17 for SQL Server' 
sql_server_name = 'IAMGROOT'
sql_server_db = 'NBA_HoopVision'

# --- Conexión SQL Server ---
print(f"🔌 Creando conexión a SQL Server: {sql_server_name}/{sql_server_db}...")
try:
    params = urllib.parse.quote_plus(
        f'DRIVER={{{sql_server_driver}}};'
        f'SERVER={sql_server_name};'
        f'DATABASE={sql_server_db};'
        f'Trusted_Connection=yes;'
    )
    sql_engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")
    sql_inspector = inspect(sql_engine)
except Exception as e:
    print(f"❌ Error fatal al conectar a SQL Server: {e}")
    sys.exit()

# --- Funciones de Inspección ---

def get_sqlite_pandas_types(db_path):
    """Lee todas las tablas de SQLite y devuelve sus Dtypes de Pandas."""
    schemas = {}
    conn = None
    print(f"\n--- 🕵️‍♂️ Inspeccionando SQLite ({db_path}) ---")
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = [row[0] for row in cursor.fetchall()]
        print(f"Tablas encontradas: {len(tables)}")

        for table_name in tables:
            try:
                # Leemos solo 1 fila para inferir tipos rápidamente
                df = pd.read_sql_query(f"SELECT * FROM \"{table_name}\" LIMIT 1", conn)
                schemas[table_name] = {col: str(dtype) for col, dtype in df.dtypes.items()}
            except Exception as e:
                print(f"   - ⚠️ No se pudo leer la tabla '{table_name}': {e}")
                schemas[table_name] = {"Error": str(e)}
        
    except Exception as e:
        print(f"❌ Error al inspeccionar SQLite: {e}")
    finally:
        if conn:
            conn.close()
    return schemas

def get_sql_server_types(inspector):
    """Lee todas las tablas de SQL Server y devuelve sus tipos."""
    schemas = {}
    print(f"\n--- 🕵️‍♀️ Inspeccionando SQL Server ({sql_server_db}) ---")
    try:
        schemas_db = inspector.get_schema_names()
        # A menudo nos interesa 'dbo', pero busquemos en todas por si acaso
        print(f"Esquemas encontrados: {schemas_db}")
        
        for schema in schemas_db:
             # Omitimos esquemas del sistema
            if schema in ['guest', 'INFORMATION_SCHEMA', 'sys', 'db_owner', 
                          'db_accessadmin', 'db_securityadmin', 'db_ddladmin', 
                          'db_backupoperator', 'db_datareader', 'db_datawriter',
                          'db_denydatareader', 'db_denydatawriter']:
                continue

            tables = inspector.get_table_names(schema=schema)
            print(f"Tablas encontradas en '{schema}': {len(tables)}")
            for table_name in tables:
                full_table_name = f"{schema}.{table_name}"
                try:
                    columns = inspector.get_columns(table_name, schema=schema)
                    schemas[table_name] = {col['name']: str(col['type']) for col in columns}
                except Exception as e:
                    print(f"   - ⚠️ No se pudo leer la tabla '{full_table_name}': {e}")
                    schemas[table_name] = {"Error": str(e)}

    except Exception as e:
        print(f"❌ Error al inspeccionar SQL Server: {e}")
    return schemas

def analyze_mismatch(pandas_type, sql_type):
    if not pandas_type or not sql_type:
        return "FALTA DATO"

    p_type = str(pandas_type).lower()
    # Para SQL Server, tomamos el tipo base (ej. 'NVARCHAR' de 'NVARCHAR(255)')
    s_type_full = str(sql_type).upper()
    s_type_base = s_type_full.split('(')[0] 

    # Casos OK (comunes)
    if p_type.startswith('int') and s_type_base in ['INT', 'INTEGER', 'BIGINT', 'SMALLINT', 'TINYINT']:
        return "✅ OK"
    if p_type.startswith('float') and s_type_base in ['FLOAT', 'REAL', 'DECIMAL', 'NUMERIC']:
        return "✅ OK"
    if p_type == 'object' and s_type_base in ['VARCHAR', 'NVARCHAR', 'TEXT', 'CHAR', 'NCHAR']:
        return "✅ OK"
    if p_type == 'bool' and s_type_base == 'BIT':
        return "✅ OK"
    if p_type.startswith('datetime64') and s_type_base in ['DATE', 'DATETIME', 'DATETIME2', 'SMALLDATETIME', 'TIME']:
        return "✅ OK"

    # Focos Rojos (comunes)
    if p_type.startswith('float') and s_type_base in ['INT', 'INTEGER', 'BIGINT', 'SMALLINT', 'TINYINT']:
        return f"🚨 ¡{p_type.upper()} vs {s_type_base}! (Necesita Int64 nullable)"
    if p_type == 'object' and s_type_base in ['INT', 'INTEGER', 'BIGINT', 'SMALLINT', 'TINYINT', 'FLOAT', 'REAL', 'DECIMAL', 'NUMERIC', 'BIT', 'DATE', 'DATETIME', 'DATETIME2']:
        return f"🚨 ¡OBJECT vs {s_type_base}! (Necesita conversión específica)"
    if p_type.startswith('int') and s_type_base == 'BIT':
        return f"⚠️ {p_type.upper()} vs BIT (¿Se mapea 0/1?)"

    # Casos menos comunes o que requieren inspección
    if p_type == 'object' and s_type_base not in ['VARCHAR', 'NVARCHAR', 'TEXT', 'CHAR', 'NCHAR']:
        return f"❓ OBJECT vs {s_type_base} (Revisar si es texto o necesita conversión)"

    return "❓ Revisar (Combinación no cubierta)"

# --- Ejecución y Comparación ---

sqlite_types = get_sqlite_pandas_types(sqlite_db_file)
sql_server_types = get_sql_server_types(sql_inspector)

print("\n\n--- 📊 Comparación de Esquemas ---")

# Usamos las tablas de SQLite como base para la comparación
all_tables = sorted(list(sqlite_types.keys()))

for table in all_tables:
    print(f"\n=======================================")
    print(f" Tabla: {table}")
    print(f"=======================================")
    
    sqlite_cols = sqlite_types.get(table, {})
    sql_cols = sql_server_types.get(table, {})

    if "Error" in sqlite_cols:
        print(f"  - Error en SQLite: {sqlite_cols['Error']}")
        continue
    if not sql_cols or "Error" in sql_cols:
        print(f"  - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!")
        continue

    all_cols = sorted(list(sqlite_cols.keys()))

    print(f"  {'Columna':<30} | {'SQLite (Pandas)':<15} | {'SQL Server':<15} | {'Análisis':<30}")
    print(f"  {'-'*30} | {'-'*15} | {'-'*15} | {'-'*30}")

    for col in all_cols:
        p_type = sqlite_cols.get(col, 'N/A')
        s_type = sql_cols.get(col, 'N/A')
        analysis = analyze_mismatch(p_type, s_type)
        print(f"  {col:<30} | {p_type:<15} | {s_type:<15} | {analysis}")

    # Verificamos si hay columnas en SQL Server que no están en SQLite
    missing_in_sqlite = [c for c in sql_cols.keys() if c not in sqlite_cols]
    if missing_in_sqlite:
        print("\n  Columnas ADICIONALES en SQL Server:")
        for col in missing_in_sqlite:
            print(f"    - {col} ({sql_cols[col]})")

print("\n--- Comparación Finalizada ---")

# Cerramos el motor de SQL Server
if sql_engine:
    sql_engine.dispose()
    print("🚪 Conexión a SQL Server cerrada.")
# Out:
# 🔌 Creando conexión a SQL Server: IAMGROOT/NBA_HoopVision...
#
# --- 🕵️‍♂️ Inspeccionando SQLite (nba.sqlite) ---
# Tablas encontradas: 16
#
# --- 🕵️‍♀️ Inspeccionando SQL Server (NBA_HoopVision) ---
# Esquemas encontrados: ['db_accessadmin', 'db_backupoperator', 'db_datareader', 'db_datawriter', 'db_ddladmin', 'db_denydatareader', 'db_denydatawriter', 'db_owner', 'db_securityadmin', 'dbo', 'guest', 'INFORMATION_SCHEMA', 'sys']
# Tablas encontradas en 'dbo': 11
#
#
# --- 📊 Comparación de Esquemas ---
#
# =======================================
#  Tabla: common_player_info
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   birthdate                      | object          | DATE            | 🚨 ¡OBJECT vs DATE! (Necesita conversión específica)
#   country                        | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   display_fi_last                | object          | NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   display_first_last             | object          | NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   display_last_comma_first       | object          | NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   dleague_flag                   | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   draft_number                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   draft_round                    | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   draft_year                     | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   first_name                     | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   from_year                      | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   games_played_current_season_flag | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   games_played_flag              | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   greatest_75_flag               | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   height                         | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   jersey                         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   last_affiliation               | object          | NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   last_name                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   nba_flag                       | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   person_id                      | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player_slug                    | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   playercode                     | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   position                       | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   rosterstatus                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   school                         | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   season_exp                     | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   team_abbreviation              | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_code                      | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id                        | int64           | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ❓ Revisar (Combinación no cubierta)
#   team_name                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   to_year                        | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   weight                         | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#
# =======================================
#  Tabla: draft_combine_stats
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   bench_press                    | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   body_fat_pct                   | object          | DECIMAL(4, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   first_name                     | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   hand_length                    | object          | DECIMAL(4, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   hand_width                     | object          | DECIMAL(4, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   height_w_shoes                 | object          | DECIMAL(5, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   height_w_shoes_ft_in           | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   height_wo_shoes                | float64         | DECIMAL(5, 2)   | ✅ OK
#   height_wo_shoes_ft_in          | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   lane_agility_time              | float64         | DECIMAL(5, 2)   | ✅ OK
#   last_name                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   max_vertical_leap              | float64         | DECIMAL(4, 2)   | ✅ OK
#   modified_lane_agility_time     | object          | DECIMAL(5, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   off_drib_college_break_left    | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   off_drib_college_break_right   | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   off_drib_college_top_key       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   off_drib_fifteen_break_left    | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   off_drib_fifteen_break_right   | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   off_drib_fifteen_top_key       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   on_move_college                | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   on_move_fifteen                | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player_id                      | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player_name                    | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   position                       | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   season                         | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   spot_college_break_left        | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_college_break_right       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_college_corner_left       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_college_corner_right      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_college_top_key           | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_fifteen_break_left        | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_fifteen_break_right       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_fifteen_corner_left       | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_fifteen_corner_right      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_fifteen_top_key           | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_nba_break_left            | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_nba_break_right           | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_nba_corner_left           | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_nba_corner_right          | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   spot_nba_top_key               | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   standing_reach                 | float64         | DECIMAL(5, 2)   | ✅ OK
#   standing_reach_ft_in           | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   standing_vertical_leap         | float64         | DECIMAL(4, 2)   | ✅ OK
#   three_quarter_sprint           | float64         | DECIMAL(5, 2)   | ✅ OK
#   weight                         | object          | DECIMAL(6, 2)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   wingspan                       | float64         | DECIMAL(5, 2)   | ✅ OK
#   wingspan_ft_in                 | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#
# =======================================
#  Tabla: draft_history
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   draft_type                     | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   organization                   | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   organization_type              | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   overall_pick                   | int64           | INTEGER         | ✅ OK
#   person_id                      | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player_name                    | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player_profile_flag            | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   round_number                   | int64           | INTEGER         | ✅ OK
#   round_pick                     | int64           | INTEGER         | ✅ OK
#   season                         | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   team_abbreviation              | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_name                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#
# =======================================
#  Tabla: game
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   ast_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   ast_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   blk_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   blk_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   dreb_away                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   dreb_home                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fg3_pct_away                   | object          | DECIMAL(5, 3)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   fg3_pct_home                   | object          | DECIMAL(5, 3)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   fg3a_away                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fg3a_home                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fg3m_away                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fg3m_home                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fg_pct_away                    | object          | DECIMAL(5, 3)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   fg_pct_home                    | object          | DECIMAL(5, 3)   | 🚨 ¡OBJECT vs DECIMAL! (Necesita conversión específica)
#   fga_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fga_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   fgm_away                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   fgm_home                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   ft_pct_away                    | float64         | DECIMAL(5, 3)   | ✅ OK
#   ft_pct_home                    | float64         | DECIMAL(5, 3)   | ✅ OK
#   fta_away                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   fta_home                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   ftm_away                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   ftm_home                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   game_date                      | object          | DATE            | 🚨 ¡OBJECT vs DATE! (Necesita conversión específica)
#   game_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   matchup_away                   | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   matchup_home                   | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   min                            | int64           | DECIMAL(5, 1)   | ❓ Revisar (Combinación no cubierta)
#   oreb_away                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   oreb_home                      | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pf_away                        | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pf_home                        | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   plus_minus_away                | int64           | INTEGER         | ✅ OK
#   plus_minus_home                | int64           | INTEGER         | ✅ OK
#   pts_away                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   pts_home                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   reb_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   reb_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   season_id                      | object          | VARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   season_type                    | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   stl_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   stl_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   team_abbreviation_away         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_abbreviation_home         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_away                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_home                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_name_away                 | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_name_home                 | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   tov_away                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   tov_home                       | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   video_available_away           | int64           | BIT             | ⚠️ INT64 vs BIT (¿Se mapea 0/1?)
#   video_available_home           | int64           | BIT             | ⚠️ INT64 vs BIT (¿Se mapea 0/1?)
#   wl_away                        | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   wl_home                        | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#
# =======================================
#  Tabla: game_info
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# =======================================
#  Tabla: game_summary
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# =======================================
#  Tabla: inactive_players
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# =======================================
#  Tabla: line_score
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   game_date_est                  | object          | DATE            | 🚨 ¡OBJECT vs DATE! (Necesita conversión específica)
#   game_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   game_sequence                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_away                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   pts_home                       | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   pts_ot10_away                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot10_home                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot1_away                   | int64           | INTEGER         | ✅ OK
#   pts_ot1_home                   | int64           | INTEGER         | ✅ OK
#   pts_ot2_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot2_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot3_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot3_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot4_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot4_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot5_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot5_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot6_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot6_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot7_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot7_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot8_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot8_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot9_away                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_ot9_home                   | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr1_away                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr1_home                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr2_away                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr2_home                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr3_away                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr3_home                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr4_away                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_qtr4_home                  | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   team_abbreviation_away         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_abbreviation_home         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city_name_away            | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city_name_home            | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_away                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_home                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_nickname_away             | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_nickname_home             | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_wins_losses_away          | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_wins_losses_home          | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#
# =======================================
#  Tabla: officials
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# =======================================
#  Tabla: other_stats
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   game_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   largest_lead_away              | int64           | INTEGER         | ✅ OK
#   largest_lead_home              | int64           | INTEGER         | ✅ OK
#   lead_changes                   | int64           | INTEGER         | ✅ OK
#   league_id                      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   pts_2nd_chance_away            | int64           | INTEGER         | ✅ OK
#   pts_2nd_chance_home            | int64           | INTEGER         | ✅ OK
#   pts_fb_away                    | int64           | INTEGER         | ✅ OK
#   pts_fb_home                    | int64           | INTEGER         | ✅ OK
#   pts_off_to_away                | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_off_to_home                | object          | INTEGER         | 🚨 ¡OBJECT vs INTEGER! (Necesita conversión específica)
#   pts_paint_away                 | int64           | INTEGER         | ✅ OK
#   pts_paint_home                 | int64           | INTEGER         | ✅ OK
#   team_abbreviation_away         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_abbreviation_home         | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city_away                 | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_city_home                 | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_away                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id_home                   | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_rebounds_away             | int64           | INTEGER         | ✅ OK
#   team_rebounds_home             | int64           | INTEGER         | ✅ OK
#   team_turnovers_away            | int64           | INTEGER         | ✅ OK
#   team_turnovers_home            | int64           | INTEGER         | ✅ OK
#   times_tied                     | int64           | INTEGER         | ✅ OK
#   total_turnovers_away           | int64           | INTEGER         | ✅ OK
#   total_turnovers_home           | int64           | INTEGER         | ✅ OK
#
# =======================================
#  Tabla: play_by_play
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   eventmsgactiontype             | int64           | INTEGER         | ✅ OK
#   eventmsgtype                   | int64           | INTEGER         | ✅ OK
#   eventnum                       | int64           | INTEGER         | ✅ OK
#   game_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   homedescription                | object          | NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" | ❓ OBJECT vs NVARCHAR COLLATE "SQL_LATIN1_GENERAL_CP1_CI_AS" (Revisar si es texto o necesita conversión)
#   neutraldescription             | object          | NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" | ❓ OBJECT vs NVARCHAR COLLATE "SQL_LATIN1_GENERAL_CP1_CI_AS" (Revisar si es texto o necesita conversión)
#   pctimestring                   | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   period                         | int64           | INTEGER         | ✅ OK
#   person1type                    | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   person2type                    | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   person3type                    | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   player1_id                     | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player1_name                   | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player1_team_abbreviation      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player1_team_city              | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player1_team_id                | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player1_team_nickname          | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_id                     | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_name                   | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_team_abbreviation      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_team_city              | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_team_id                | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player2_team_nickname          | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_id                     | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_name                   | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_team_abbreviation      | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_team_city              | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_team_id                | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   player3_team_nickname          | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   score                          | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   scoremargin                    | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   video_available_flag           | object          | BIT             | 🚨 ¡OBJECT vs BIT! (Necesita conversión específica)
#   visitordescription             | object          | NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" | ❓ OBJECT vs NVARCHAR COLLATE "SQL_LATIN1_GENERAL_CP1_CI_AS" (Revisar si es texto o necesita conversión)
#   wctimestring                   | object          | NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#
# =======================================
#  Tabla: player
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   first_name                     | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   full_name                      | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   id                             | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   is_active                      | int64           | BIT             | ⚠️ INT64 vs BIT (¿Se mapea 0/1?)
#   last_name                      | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#
# =======================================
#  Tabla: team
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   abbreviation                   | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   city                           | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   full_name                      | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   id                             | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   nickname                       | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   state                          | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   year_founded                   | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#
# =======================================
#  Tabla: team_details
# =======================================
#   Columna                        | SQLite (Pandas) | SQL Server      | Análisis
#   ------------------------------ | --------------- | --------------- | ------------------------------
#   abbreviation                   | object          | NVARCHAR(10) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   arena                          | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   arenacapacity                  | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#   city                           | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   dleagueaffiliation             | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   facebook                       | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   generalmanager                 | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   headcoach                      | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   instagram                      | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   nickname                       | object          | NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   owner                          | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   team_id                        | object          | NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   twitter                        | object          | NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" | ✅ OK
#   yearfounded                    | float64         | INTEGER         | 🚨 ¡FLOAT64 vs INTEGER! (Necesita Int64 nullable)
#
# =======================================
#  Tabla: team_history
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# =======================================
#  Tabla: team_info_common
# =======================================
#   - ⚠️ ¡Tabla NO encontrada o con Error en SQL Server!
#
# --- Comparación Finalizada ---
# 🚪 Conexión a SQL Server cerrada.
